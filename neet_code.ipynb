# %% [markdown]
# <a href="https://colab.research.google.com/github/Manireddy69/DSA/blob/main/neet_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [2,3,4]
target = 6
def f(n,k):
  for i in range(len(n)-1):
    for j in range(i+1, len(n)):
      if n[i] + n[j] == k:
        return [i] + [j]
f(numbers,target)
# Out:
# [0, 2]

# %%
nums = [1,4,1,2]
def f(nums):
  n = len(nums)
  ans = [0] * (2 * n) # Initialize ans with appropriate size
  for i in range(n):
    ans[i] = nums[i] # Use assignment operator =
    ans[i + n] = nums[i] # Use assignment operator =
  return ans
f(nums)
# Out:
# [1, 4, 1, 2, 1, 4, 1, 2]

# %%
strs = ["bat","bag","bank","band"]
def f(strs):
  if not strs: return ""
  prefix = strs[0]
  for word in strs[1:]:
    while not word.startswith(prefix):
      prefix = prefix [:-1]
      if not prefix:
        return ""
  return prefix
f(strs)
# Out:
# 'ba'

# %%
strs = ["act","pots","tops","cat","stop","hat"]
def f(strs):
  map = {}
  for s in strs:
    key = ''.join(sorted(s))
    map.setdefault(key, []).append(s)
  return list(map.values())
f(strs)
# Out:
# [['act', 'cat'], ['pots', 'tops', 'stop'], ['hat']]

# %%
nums = [2,-1,1,2]
k = 2
def f(nums, k):
  count = 0
  curr = 0
  map = {0:1}
  for num in nums:
    curr += num
    if curr -k in map:
      count += map[curr-k]
    map[curr] = map.get(curr, 0) +1
  print(map)
  return count
f(nums, k)
# Out:
# {0: 1, 2: 2, 1: 1, 4: 1}
# 4

# %%
d = {0:1, 2:3}
d.get(4, 0)
# Out:
# 0

# %%
prices = [10,1,5,6,7,1]
def f(prices):
  profit = 0
  for i in range(1,len(prices)):
    if prices[i] > prices[i-1]:
      profit += prices[i] -prices[i-1]
  return profit
f(prices)
# Out:
# 6

# %%
print('hi')
# Out:
# hi

# %%
s = "zxyzxyz"
def f(s):
  left = 0
  max_len = 0
  seen = set()
  for right in range(len(s)):
    while s[right] in seen:
      seen.remove(s[left])
      left += 1
    seen.add(s[right])
    max_len = max(max_len, right - left + 1)
  return max_len

f(s)
# Out:
# 3

# %%
s ="mani"
s.startswith('m')
# Out:
# True

# %%
nums = [2,-1,1,2]
k = 2
def f(nums, k):
  result = 0
  for num in nums:
    if num == k:
      count += 1

# %%
# Out:
# [0, 0, 10, 20, 20, 40]

# %%
people = [1,3,2,3,2]
limit = 3
def boat(people, limit):
  count = 0
  for num in people:
    if num == limit:
      count += 1
  for i in range(len(people)):
    for j in range(i+1, len(people)):
      if people[i] + people[j] == limit:
        count += 1
  return count
boat(people, limit)

#time complexity: O(n ^ 2)
# Out:
# 4

# %%
nums = [1,1,2,3,4]
nums[:] = list(set(nums))
print(nums)
# Out:
# [1, 2, 3, 4]

# %%
people = [1,3,2,3,2]
limit = 3
def boats(people, limit):
  people.sort()
  l = 0
  h = len(people)-1
  count = 0
  while l<= h:
    if people[l] + people[h] <= limit:
      l += 1
    h -= 1
    count +=1
  return count
boats(people, limit)
# Out:
# 4

# %%
s = "pwwke"
def f(s):
  l = list(set(list(s)))
  if len(l) == 1:
    return 1
  count = 0
  for i in range(len(l)):
    for j in range(i+1, len(l)):
      if l[i] != l[j]:
        count += 1
  return count
f(s)
# Out:
# 3

# %%
nums = [-1,0,1,2,-1,-4]
def t(n):
  result  = []
  for i in range(len(n)-1):
    for j in range(i+1, len(n)):
      for k in range(j+1, len(n)):
        if n[i] + n[j] + n[k] == 0:
          s = sorted([n[i], n[j], n[k]])
          if s not in result:
            result.append(s)
  return result
t(nums)
# Out:
# [[-1, 0, 1], [-1, -1, 2]]

# %%
s="aec"
t="abcde"
def d(s,t):
  i = 0 # pointer for s
  j = 0 # pointer for t
  while i < len(s) and j < len(t):
    if s[i] == t[j]:
      i += 1
    j += 1
  return i == len(s) # True if all characters of s were found in order
d(s,t)
# Out:
# False

# %%
t = "neetcode"
d = list(t)
''.join(d)
# Out:
# 'neetcode'

# %%
height=[2,2,2]
def calculate_max_area(height_list):
  l = 0
  r = len(height_list) -1
  area = 0
  while l < r:
    # Note: (r-1) might be a logical error, usually it's (r-l) for width calculation
    a = (min(height_list[l], height_list[r])) *(r-1)
    area = max(area,a)
    if height_list[l] <= height_list[r]:
      l +=1
    else:
      r -= 1
  return area
calculate_max_area(height)
# Out:
# 2

# %%
nums = [3,2,3,-3,1,0]
target = 3
def f(nums, target):
  nums.sort()
  result = set()
  for a in range(len(nums)):
    for b in range(a+1, len(nums)):
      for c in range(b+1, len(nums)):
        for d in range(c+1, len(nums)):
          if nums[a] + nums[b] + nums[c] + nums[d] == target:
            # Use .add() for sets, not .append()
            result.add((nums[a],nums[b], nums[c] ,nums[d]))
  return list(result)
f(nums, target)
# Out:
# [(-3, 1, 2, 3), (-3, 0, 3, 3)]

# %%
nums = [1,2,3,4,5,6,7,8]
k = 4
def f(nums, k):
  # if not nums:
  #   return
  n = len(nums)
  k = k % n
  if k == 0:
    return
  nums[:] = nums[n-k:] + nums[:n-k]
f(nums, k)
print(nums)
# Out:
# [5, 6, 7, 8, 1, 2, 3, 4]

# %%
4 % 8
# Out:
# 4

# %%
nums=[1,0,1,1]
k=1
def f(nums,k):
  for i in range(len(nums)-1):
    for j in range(i+1, len(nums)):
      if nums[i] == nums[j]:
        return abs(i -j) <= k
  return False
f(nums, k)
# Out:
# False

# %%
prices = [10,1,5,6,7,1]
def price(prices):
  if prices == sorted(prices, reverse= True):
    return 0
  min = 0
  max = 0
  for i in range(len(prices)-1):
    m = prices[i]
    for j in range(i+1, len(proces)):
      if m < prices[j]:
        min += prices[j]
      break

# %%
float('inf')
# Out:
# inf

# %%
prices = [10,8,7,5,2]
prices == sorted(prices, reverse = True)
# Out:
# True

# %%
l = [1,1]
l[0]
# Out:
# 1

# %%
word1 = "abc"
word2 = "xyz"
def f(x,y):
  l1 = list(x)
  l2 = list(y)
  result  = [i]

# %%
l1 = list(word1)
l2 = list(word2)

result_list = []
max_len = max(len(l1), len(l2))

for i in range(max_len):
    char1 = l1[i] if i < len(l1) else ''
    char2 = l2[i] if i < len(l2) else ''
    result_list.append(char1 + char2)

final_word = "".join(result_list)
final_word
# Out:
# 'axbycz'

# %%
nums = [5,5,1,1,1,5,5]
def d(nums):
  s= set(nums)
  d = {[i] == 0 for i in s}

# %%
nums=[9,1,4,7,3,-1,0,5,8,-1,6]
def num(nums):

  s = list(sorted(set(nums)))
  l = len(s)
  result = 1
  for i in range(1,l):
    if s[i] == s[i-1] +1:
      result += 1
  return result

num(nums)
# Out:
# 9

# %%
nums = [2,-1,1,2]
k = 2
def f(n,k):
  l = len(n)
  count = 0
  for i in range(l):
    if n[i] == k:
      count += 1
    else :

# %%
nums = [1,2,4,5,6,3,1]
def f(n):
  nums = list(set(nums.sort()))

# %%
s = ["n","e","e","t"]
def f(s):
  result = []
  for i in range(len(s)-1,-1,-1):
    result.append(s[i])
  return(result)
f(s)
# Out:
# ['t', 'e', 'e', 'n']

# %%
l = [1,2,3]
list(sorted(set(l)))
# Out:
# [1, 2, 3]

# %%
s ="tab a cat"
def plaindrome(s):
  result  = []
  l = list(s.lower())
  for char in l:
    if char.isalpha():
      result.append(char)
  return result[:] == result [::-1]
plaindrome(s)
# Out:
# False

# %%
l = list(s.lower())
l[0].isalpha()
# Out:
# True

# %%
s = "abbda"
def plaindrome_2(s):
  s = list(s)
  if s[:] == s[::-1]:
    return True
  result = []
  l = len(s)
  for i in range(l):
    s.remove(s[i])
    return s[:] == s[::-1]
plaindrome_2(s)
# Out:
# False

# %%
s = 'aca'
l = list(s)
result = []
l.remove('a')
result.append(l)
result
# Out:
# [['c', 'a']]

# %%
nums = [1,2,3]
k = 2
s = set(nums)
d = {i: 0 for i in s}
for i in range(len(nums)):
  if nums[i] in list(d.keys()):
    d[nums[i]] += 1
result = [key for key, val in d.items() if val %3 == k]
result
# Out:
# []

# %%
# Out:
#   File "/tmp/ipython-input-780/3472694100.py", line 2
#     def f(nums):
#                 ^
# SyntaxError: incomplete input

# %%
red # Display the dictionary

# Get the key from 'd' that has the maximum value
max_value_key = max(d, key=d.get)
max_value_key
d.get
# Out:
# <function dict.get(key, default=None, /)>

# %%
nums = [-1,0,1,2,3]
def k(nums):
  result = []
  for i in range(len(nums)):
    product = 1
    for j in range(len(nums)):
      if i != j:
        product *= nums[j]
    result.append(product)
  return result
k(nums)
# Out:
# [0, -6, 0, 0, 0]

# %%
def f(nums):
  result = []
  for i in range(len(nums)):
    product = 1
    for j in range(len(nums)):
      if i != j:
        # product = 1
        product *= nums[j]
    result .append(product)
  return result
f(nums)
# Out:
# [0, -6, 0, 0, 0]
